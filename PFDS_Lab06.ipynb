# %% [markdown]
# <a href="https://colab.research.google.com/github/PoojithaYarava/Python-For-Data-Science-/blob/main/PFDS_Lab06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.Clean and Preprocess a Real-World Dataset (e.g., Sales Dataset) for
# Analysis.
#
# Sales Dataset – Removing Duplicates

# %%
import pandas as pd

# Create a sample sales dataset with duplicate entries
data = {
    'Transaction_ID': [1, 2, 3, 4, 5, 1, 6, 7, 8, 3],
    'Product': ['A', 'B', 'C', 'D', 'E', 'A', 'F', 'G', 'H', 'C'],
    'Price': [100, 200, 150, 300, 250, 100, 120, 180, 220, 150],
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05', '2023-01-01', '2023-01-06', '2023-01-07', '2023-01-08', '2023-01-03']
}
sales_df = pd.DataFrame(data)

print("Original DataFrame:")
display(sales_df)
# Out:
# Original DataFrame:
#    Transaction_ID Product  Price        Date
# 0               1       A    100  2023-01-01
# 1               2       B    200  2023-01-02
# 2               3       C    150  2023-01-03
# 3               4       D    300  2023-01-04
# 4               5       E    250  2023-01-05
# 5               1       A    100  2023-01-01
# 6               6       F    120  2023-01-06
# 7               7       G    180  2023-01-07
# 8               8       H    220  2023-01-08
# 9               3       C    150  2023-01-03

# %%
# Identify duplicates
duplicate_rows = sales_df[sales_df.duplicated()]
print("\nDuplicate Rows:")
display(duplicate_rows)

# Before duplicate count
print(f"\nNumber of rows before removing duplicates: {len(sales_df)}")

# Remove duplicates
sales_df_cleaned = sales_df.drop_duplicates()

# After duplicate count
print(f"Number of rows after removing duplicates: {len(sales_df_cleaned)}")

print("\nDataFrame after removing duplicates:")
display(sales_df_cleaned)
# Out:
# Duplicate Rows:
#    Transaction_ID Product  Price        Date
# 5               1       A    100  2023-01-01
# 9               3       C    150  2023-01-03
# Number of rows before removing duplicates: 10
# Number of rows after removing duplicates: 8
#
# DataFrame after removing duplicates:
#    Transaction_ID Product  Price        Date
# 0               1       A    100  2023-01-01
# 1               2       B    200  2023-01-02
# 2               3       C    150  2023-01-03
# 3               4       D    300  2023-01-04
# 4               5       E    250  2023-01-05
# 6               6       F    120  2023-01-06
# 7               7       G    180  2023-01-07
# 8               8       H    220  2023-01-08

# %% [markdown]
# -

# %% [markdown]
# 4.Clean and Preprocess a Real-World Dataset (e.g., Employee Dataset) for
# Analysis.
#
# Employee Dataset – Converting Data Types

# %%
import pandas as pd

# Create a sample employee dataset with incorrect data types
employee_data = {
    'Employee_ID': [101, 102, 103, 104, 105],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Salary': ['50000', '60000', '45000', '70000', '55000'],
    'Joining_Date': ['2022-01-15', '2021-08-20', '2023-03-10', '2020-11-01', '2022-06-25']
}
employee_df = pd.DataFrame(employee_data)

print("Original DataFrame with incorrect data types:")
display(employee_df)
print("\nOriginal data types:")
display(employee_df.dtypes)

# Convert 'Salary' to numeric
employee_df['Salary'] = pd.to_numeric(employee_df['Salary'])

# Convert 'Joining_Date' to datetime
employee_df['Joining_Date'] = pd.to_datetime(employee_df['Joining_Date'])

print("\nDataFrame after converting data types:")
display(employee_df)
print("\nCorrected data types:")
display(employee_df.dtypes)
# Out:
# Original DataFrame with incorrect data types:
#    Employee_ID     Name Salary Joining_Date
# 0          101    Alice  50000   2022-01-15
# 1          102      Bob  60000   2021-08-20
# 2          103  Charlie  45000   2023-03-10
# 3          104    David  70000   2020-11-01
# 4          105      Eve  55000   2022-06-25
# Original data types:
# Employee_ID      int64
# Name            object
# Salary          object
# Joining_Date    object
# dtype: object
# DataFrame after converting data types:
#    Employee_ID     Name  Salary Joining_Date
# 0          101    Alice   50000   2022-01-15
# 1          102      Bob   60000   2021-08-20
# 2          103  Charlie   45000   2023-03-10
# 3          104    David   70000   2020-11-01
# 4          105      Eve   55000   2022-06-25
# Corrected data types:
# Employee_ID              int64
# Name                    object
# Salary                   int64
# Joining_Date    datetime64[ns]
# dtype: object
